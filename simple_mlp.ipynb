# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np

# XOR Dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

Y = np.array([
    [0],
    [1],
    [1],
    [0]
])

model = Sequential([
    Input(shape=(2,)),
    Dense(4, activation='sigmoid'),  
    Dense(1, activation='sigmoid')                    
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(X, Y, epochs=5000, verbose=0)

predictions = model.predict(X)

print("Predictions:")
print(predictions)

loss, acc = model.evaluate(X, Y, verbose=0)
print(acc)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780899193.775148    4947 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780899194.253130    4947 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780899198.030542    4947 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780899202.429667    4947 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2140 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1780899204.536682    5559 service.cc:153] XLA service 0x7ddf900301b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780899204.536719    5559 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2050, Compute Capability 8.6 (Driver: 13.0.0; Runtime: 12.8.0; Toolkit: 12.5.0; DNN: 9.23.0)
# I0000 00:00:1780899204.577697    5559 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1780899204.825798    5559 cuda_dnn.cc:461] Loaded cuDNN version 92300
# I0000 00:00:1780899204.838366    5559 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1038__.8
# I0000 00:00:1780899205.447404    5559 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Predictions:
# [[0.01626931]
#  [0.97767866]
#  [0.8955378 ]
#  [0.11973689]]
# 1.0
